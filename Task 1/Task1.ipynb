# %% [markdown]
# ## TASK 1
# ## Exploring and Visualizing a Simple Dataset
# # Objective
# Learn how to load, inspect, and visualize a dataset to understand data trends and distributions.
# # Introduction
# Task 1 focuses on exploring and analyzing the famous Iris dataset, which is a classic dataset in AI and Machine Learning, often used for classification problems. It contains measurements of iris flowers from three species — setosa, versicolor, and virginica. The aim of this task is to load the dataset, explore its structure, perform statistical analysis, and visualize the relationships between features such as sepal length, sepal width, petal length, and petal width. By doing so, the task builds a strong foundation for handling real-world datasets, enabling a better understanding of data before applying machine learning algorithms.
# # Overview
# In this task, the dataset was loaded using the seaborn library, and explored using pandas. Commands such as .shape, .head(), and .info() were used to understand the structure and size of the dataset, while .describe() provided summary statistics for each feature. For data visualization, tools like matplotlib and seaborn were used to create scatterplots, histograms, and boxplots. These visualizations helped in identifying patterns, relationships between variables, and possible outliers. For example, scatterplots were used to compare sepal length and petal length, separated by species using color coding, while boxplots and histograms helped understand distributions and variations in measurements. Through these steps, essential skills in data handling, analysis, and visualization were developed.
#
# # Summary
# Overall, Task 1 provided practical experience in data loading, exploration, and visualization — all of which are critical steps in any AI/ML workflow. The key skills learned include using pandas for data inspection, applying .shape, .head(), .info(), and .describe() for structural and statistical understanding, and leveraging matplotlib and seaborn to create insightful visualizations. These skills ensure that datasets can be effectively analyzed and prepared for machine learning models.

# %%
# Step 1  Importing the Required Libraries
import pandas as pd              # Tool for loading and analyzing data
import seaborn as sns            # Tool for drawing graphs
import matplotlib.pyplot as plt  # Basic graph


# Step 2: Loading the Iris Dataset
iris = sns.load_dataset('iris')  # Loading the iris dataset from seaborn


#Step 3: Explore the Dataset
# 1.shape
print("Shape:", iris.shape)              # rows and coulombs of the dataset
# 2.column names
print("Columns:", iris.columns.tolist()) # columns present
# 3.First Few Rows
print(iris.head())                       # first 5 or as required
# 4.Info
print(iris.info())                       # type and missing data
# 5.stats
print(iris.describe())                   # min,max,mean,standard deviation



# Step 4: Visualize the Data graphically for easier pattern recognization
# 1.Scatter Plot
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species') # See how two features are related that are sepal and petal lengths 
plt.title("Sepal Length vs Petal Length")                                     # seperated by species based on colour
plt.show()
# 2.Histogram
iris.hist(edgecolor='black', figsize=(10, 6))  # This shows how values are distributed and in which ranges they are present
plt.suptitle("Feature Distributions")
plt.tight_layout()
plt.show()
# 3.Box Plot
sns.boxplot(data=iris)
plt.title("Boxplot of Iris Features")       # It is used to explain the spreadness of data and that if their are any anomaly or outlier (shown by holes) 
plt.show()
# Out:
# Shape: (150, 5)
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
# ...
